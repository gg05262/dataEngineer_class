# %%
import numpy as np  
import matplotlib.pyplot as plt  
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# %matplotlib qt5
# %config InlineBackend.figure_format = 'svg'

plt.rcParams['figure.figsize'] = [12, 5]
plt.rcParams['font.size'] = 13
plt.ion()

# %%
def f(z):
    return np.power(z,2)-1

# %%
f(0)
# Out:
# -1

# %%
z=[4,1-0.2j,1.6]
f(z)
# Out:
# array([15.  +0.j , -0.04-0.4j,  1.56+0.j ])

# %%
x,y = np.meshgrid(np.linspace(-10,10,20), np.linspace(-10,10,20))

# %%
mesh = y*1j + x

# %%
output = np.abs(f(mesh))

# %%
output
# Out:
# array([[200.00249998, 180.16891204, 162.56186183, 147.17961999,
#         134.01873672, 123.07358959, 114.33622352, 107.7967979 ,
#         103.44488499, 101.27153785, 101.27153785, 103.44488499,
#         107.7967979 , 114.33622352, 123.07358959, 134.01873672,
#         147.17961999, 162.56186183, 180.16891204, 200.00249998],
#        [179.94737695, 160.11392613, 142.51023925, 127.13547771,
#         113.98681334, 103.05855538,  94.34149584,  87.82304255,
#          83.48877541,  81.32559793,  81.32559793,  83.48877541,
#          87.82304255,  94.34149584, 103.05855538, 113.98681334,
#         127.13547771, 142.51023925, 160.11392613, 179.94737695],
#        [162.09770634, 142.26121806, 124.65775066, 109.28788896,
#          96.15018387,  85.2396981 ,  76.54644979,  70.05464703,
#          65.74414657,  63.5951671 ,  63.5951671 ,  65.74414657,
#          70.05464703,  76.54644979,  85.2396981 ,  96.15018387,
#         109.28788896, 124.65775066, 142.26121806, 162.09770634],
#        [146.45510629, 126.6114754 , 109.00363669,  93.63414895,
#          80.50396816,  69.6103707 ,  60.94398894,  54.48600106,
#          50.20826791,  48.07989129,  48.07989129,  50.20826791,
#          54.48600106,  60.94398894,  69.6103707 ,  80.50396816,
#          93.63414895, 109.00363669, 126.6114754 , 146.45510629],
#        [133.0229071 , 113.16732758,  95.54905757,  80.17295862,
#          67.04346934,  56.16225281,  47.52357679,  41.10765254,
#          36.87611379,  34.77908791,  34.77908791,  36.87611379,
#          41.10765254,  47.52357679,  56.16225281,  67.04346934,
#          80.17295862,  95.54905757, 113.16732758, 133.0229071 ],
#        [121.80664657, 101.93426766,  84.29857262,  68.906435  ,
#          55.76627395,  44.88648685,  36.27018664,  29.90323903,
#          25.73774249,  23.69130817,  23.69130817,  25.73774249,
#          29.90323903,  36.27018664,  44.88648685,  55.76627395,
#          68.906435  ,  84.29857262, 101.93426766, 121.80664657],
#        [112.81429713,  92.92141766,  75.26184375,  59.84317672,
#          46.67667466,  35.77805717,  27.16522653,  20.84441446,
#          16.77177714,  14.81306206,  14.81306206,  16.77177714,
#          20.84441446,  27.16522653,  35.77805717,  46.67667466,
#          59.84317672,  75.26184375,  92.92141766, 112.81429713],
#        [106.05588371,  86.14154646,  68.45470709,  53.0015804 ,
#          39.79281224,  28.84707686,  20.19645554,  13.88646859,
#           9.92815754,   8.13439089,   8.13439089,   9.92815754,
#          13.88646859,  20.19645554,  28.84707686,  39.79281224,
#          53.0015804 ,  68.45470709,  86.14154646, 106.05588371],
#        [101.54219089,  81.60959693,  63.89802523,  48.41058612,
#          35.15320818,  24.13820613,  15.39386822,   8.9910945 ,
# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter(x,y,output,alpha=0.2)

ax.set_xlabel('Real axis')
ax.set_ylabel('Imainary axis')
ax.set_zlabel('Absolute value')
ax.set_title('One Iteration: $f(z) = z^2 -1$');

# %%
output1 = np.abs(f(f(mesh)))
ax=plt.axes(projection='3d')

ax.scatter(x,y,output1,alpha=0.2)
ax.set_xlabel('Real axis')
ax.set_ylabel('Imainary axis')
ax.set_zlabel('Absolute value')
ax.set_title('Two Iteration: $f(z) = z^2 -1$');

# %%
selected_values = np.array([0.4 + 0.4j, 0.41 + 0.4j, 0.4 + 0.41j])
num_iter = 9

outputs = np.zeros(
    (num_iter+1, selected_values.shape[0]),  # 10X3 Zero 배열 생성
    dtype=complex  # 데이터 타입: 복소수
)
outputs[0] = selected_values   # 함수 초기 조건

for i in range(num_iter):
    outputs[i+1] = f(outputs[i])  # 10번 함수 반복하는 동안 각 결과를 저장

fig, axes = plt.subplots(1, selected_values.shape[0], figsize=(16, 6))
axes[1].set_xlabel('Real axis')
axes[0].set_ylabel('Imaginary axis')

for ax, data in zip(axes, outputs.T):
    cycle = ax.scatter(
        data.real,  # 실수부
        data.imag,  # 허수부
        c=range(data.shape[0]), 
        alpha=0.6
    )
    ax.set_title(f'Mapping of iterations on {data[0]}')

fig.colorbar(cycle, ax=axes, location='bottom', label='Iteration');

# %%
'''
def divergence_rate(mesh, num_iter=10, radius=2):

    z = mesh.copy()
    # 값 별 반복 횟수를 저장
    diverge_len = np.zeros(mesh.shape)

    # 발산되지 않은 값들에 대해 함수를 반복 적용
    for i in range(num_iter):
        # [+] 1. Boolean 배열  마스크 생성
        conv_mask = (np.abs(z) < radius)

        # [+] 2. 해당 값들에 대한 diverge_len 값 증가
        diverge_len[conv_mask] =1

        # [+] 3. 해당 값들에 대해 함수 적용
        z[conv_mask]= f(z[conv_mask])

    return diverge_len
'''

# %%
def divergence_rate(mesh, num_iter=10, radius=2):
    z = mesh.copy()
    # 값 별 반복 횟수를 저장
    diverge_len = np.zeros(mesh.shape)

    # 발산되지 않은 값들에 대해 함수를 반복 적용
    for i in range(num_iter):
        # [+] 1. Boolean 배열  마스크 생성
        conv_mask = (np.abs(z) < radius)

        # [+] 2. 해당 값들에 대한 diverge_len 값 증가
        diverge_len[conv_mask] += 1

        # [+] 3. 해당 값들에 대해 함수 적용
        z[conv_mask] = f(z[conv_mask])

    return diverge_len

# %%
x, y = np.meshgrid(np.linspace(-2, 2, 400), np.linspace(-2, 2, 400))
mesh = x + (1j * y)

output = divergence_rate(mesh)

fig = plt.figure(figsize=(5, 5))
ax = plt.axes()

ax.set_title('$f(z) = z^2-1$')
ax.set_xlabel('Real axis')
ax.set_ylabel('Imaginary axis')

im = ax.imshow(output, extent=[-2, 2, -2, 2])
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.1)
plt.colorbar(im, cax=cax, label='Number of iterations');
